# %% [markdown]
# # Ngày 4 - Từ 17 cái chấm của bạn đến một model pose
#
# Notebook này chạy **sau** khi nhãn của bạn đã qua cổng gold (`tools/evaluate_pose_annotations.py`).
# Trình tự: kiểm nhãn -> đo model gốc -> fine-tune trên nhãn của bạn -> đo lại -> nhìn tận mắt.
#
# ## Hợp đồng chạy
#
# - Chọn **một** cách đưa bài của bạn lên Colab: clone fork GitHub ở cell 0 (khuyến nghị), hoặc upload/mount thư mục `Day4-Lab/`.
# - Nếu clone fork: push `dataset/labels/train/`, `annotations/`, `reports/`, `outputs/` và `GUIDELINE_MINI.md` lên **fork của bạn** trước.
# - **Không** upload protected reference. Nếu bạn có `gold/`, nó cũng không được dùng để train.
# - Chạy từ trên xuống. Không đổi `val` trong `data.yaml` sang tập train để làm đẹp số.
# - 20 ảnh là quá ít để ra một model dùng được. Cái bạn đo hôm nay là **vòng lặp dữ liệu**,
#   không phải chất lượng sản phẩm. Con số quan trọng là *chênh lệch* giữa trước và sau fine-tune.

# %% [markdown]
# ## 0. Đưa fork của bạn vào Colab (khuyến nghị)
#
# Dán URL HTTPS của **fork có nhãn của bạn** vào `REPO_URL`, rồi chạy cell dưới. Cell này không xoá hoặc ghi đè thư mục nào.
#
# Nếu bạn đã upload/mount `Day4-Lab/`, để `REPO_URL` trống và chạy cell dưới để bỏ qua bước clone.

# %%
import subprocess
from pathlib import Path

# Ví dụ: https://github.com/ten-github-cua-ban/Day4-KeypointPose-Student.git
# Để trống nếu bạn upload/mount thư mục Day4-Lab thay vì clone fork.
REPO_URL = ""
WORKDIR = Path('/content') if Path('/content').is_dir() else Path.cwd()
LAB_ROOT = WORKDIR / 'Day4-Lab'

if REPO_URL.strip():
    if '<' in REPO_URL or '>' in REPO_URL:
        raise ValueError('Hãy thay REPO_URL bằng URL HTTPS của fork GitHub của bạn.')
    if (LAB_ROOT / 'data.yaml').is_file():
        print(f'Đã có repo tại {LAB_ROOT}; dùng bản hiện có.')
    elif LAB_ROOT.exists():
        raise RuntimeError(f'{LAB_ROOT} đã tồn tại nhưng không phải repo Day 4 hợp lệ. Đổi tên hoặc xoá thủ công rồi chạy lại.')
    else:
        subprocess.run(['git', 'clone', '--depth', '1', REPO_URL, str(LAB_ROOT)], check=True)
        print(f'Đã clone fork vào {LAB_ROOT}')
else:
    print('Bỏ qua clone. Hãy upload hoặc mount thư mục Day4-Lab trước khi chạy cell kế tiếp.')
# Out:
# Bỏ qua clone. Hãy upload hoặc mount thư mục Day4-Lab trước khi chạy cell kế tiếp.

# %%
# %pip -q install -U ultralytics

import json
import sys
from pathlib import Path

import torch
import yaml
from ultralytics import YOLO

# Cell 0 đã đặt LAB_ROOT khi bạn clone fork. Với upload/mount, đặt đúng đường dẫn ở đây.
LAB_ROOT = globals().get('LAB_ROOT', Path('/content/Day4-Lab'))
if not (LAB_ROOT / 'data.yaml').is_file():
    LAB_ROOT = Path.cwd() if (Path.cwd() / 'data.yaml').exists() else Path.cwd().parent
assert (LAB_ROOT / 'data.yaml').exists(), f'Không thấy data.yaml trong {LAB_ROOT}'

TRAIN_IMAGES = LAB_ROOT / 'dataset/images/train'
TRAIN_LABELS = LAB_ROOT / 'dataset/labels/train'
TEST_IMAGES = LAB_ROOT / 'dataset/images/test'
TEST_LABELS = LAB_ROOT / 'dataset/labels/test'
OUTPUTS = LAB_ROOT / 'outputs'
RUNS = OUTPUTS / 'runs'
OUTPUTS.mkdir(parents=True, exist_ok=True)
sys.path.insert(0, str(LAB_ROOT / 'tools'))

# Sinh data_colab.yaml trỏ 'path' vào đúng nơi vừa upload. File data.yaml gốc
# trong repo giữ nguyên, nên bạn commit lại mà không bị lệch đường dẫn.
config = yaml.safe_load((LAB_ROOT / 'data.yaml').read_text())
config['path'] = str(LAB_ROOT)
DATA_YAML = LAB_ROOT / 'data_colab.yaml'
DATA_YAML.write_text(yaml.safe_dump(config, sort_keys=False, allow_unicode=True))

DEVICE = 0 if torch.cuda.is_available() else 'cpu'
MODEL_NAME = 'yolo26n-pose.pt'   # đổi sang 'yolo11n-pose.pt' nếu muốn so hai thế hệ
print('LAB_ROOT :', LAB_ROOT)
print('device   :', DEVICE, '|', torch.cuda.get_device_name(0) if DEVICE == 0 else 'CPU - sẽ chậm')
print('kpt_shape:', config['kpt_shape'], '| flip_idx:', config['flip_idx'])
assert config['kpt_shape'] == [17, 3], 'kpt_shape phải là [17, 3], nếu không cờ visibility đã bị vứt'
# Out:
# Note: you may need to restart the kernel to use updated packages.
# LAB_ROOT : /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose
# device   : cpu | CPU - sẽ chậm
# kpt_shape: [17, 3] | flip_idx: [0, 2, 1, 4, 3, 6, 5, 8, 7, 10, 9, 12, 11, 14, 13, 16, 15]

# %% [markdown]
# ## 1. Kiểm nhãn trước khi train
#
# Chạy đúng script bạn đã chạy ở local: 56 số một dòng, cờ chỉ nhận 0/1/2, đủ file cho từng ảnh.
# Một file nhãn hỏng ở đây sẽ thành một model hỏng ở dưới, mà không có dòng cảnh báo nào.

# %%
import subprocess

result = subprocess.run(
    [sys.executable, str(LAB_ROOT / 'tools/check_pose_labels.py'),
     '--images', str(TRAIN_IMAGES), '--labels', str(TRAIN_LABELS)],
    capture_output=True, text=True)
print(result.stdout or result.stderr)
assert result.returncode == 0, 'Nhãn train chưa đạt định dạng - sửa trước khi train'

from poselib import parse_yolo_pose_file

def count(label_dir):
    files = sorted(label_dir.glob('*.txt'))
    people = [p for f in files for p in parse_yolo_pose_file(f)]
    flags = [v for p in people for _, _, v in p.keypoints]
    return len(files), len(people), flags.count(2), flags.count(1), flags.count(0)

for name, directory in (('train (nhãn của bạn)', TRAIN_LABELS), ('test  (nhãn phát sẵn)', TEST_LABELS)):
    files, people, v2, v1, v0 = count(directory)
    print(f'{name}: {files} file, {people} skeleton, v=2 {v2}, v=1 {v1}, v=0 {v0}')
# Out:
# Đã đọc 20/20 file nhãn, 28 skeleton.
# Cờ visibility: v=2 322 | v=1 75 | v=0 79
#
# CẢNH BÁO (8) - không chặn nộp, nhưng phải xem lại:
# - train_02.txt:1: có 4 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
# - train_06.txt:1: có 5 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
# - train_11.txt:1: có 7 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
# - train_13.txt:1: có 5 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
# - train_13.txt:2: có 4 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
# - train_14.txt:2: có 6 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
# - train_15.txt:1: có 4 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
# - train_15.txt:2: có 5 khớp v=0 nhưng box cách mọi mép ảnh trên 3%. Hãy mở ảnh kiểm tra: khớp bị che nhưng vẫn ở trong ảnh phải là v=1; chỉ khớp thật sự ra ngoài ảnh mới là v=0
#
# ĐẠT định dạng. Chạy tiếp tools/visibility_report.py, rồi chờ gold để chấm chất lượng.
#
# train (nhãn của bạn): 20 file, 28 skeleton, v=2 322, v=1 75, v=0 79
# test  (nhãn phát sẵn): 10 file, 13 skeleton, v=2 146, v=1 29, v=0 46

# %% [markdown]
# ## 2. Model gốc, chưa học gì từ nhãn của bạn
#
# `yolo26n-pose.pt` đã được train sẵn trên COCO - tức là nó **đã biết** bộ 17 điểm này.
# Đo nó trên tập test trước, để lát nữa có mốc mà so. Đây là baseline, không phải đối thủ.

# %%
baseline_model = YOLO(MODEL_NAME)
baseline_metrics = baseline_model.val(
    data=str(DATA_YAML), split='val', device=DEVICE, plots=False,
    project=str(RUNS), name='baseline', exist_ok=True)

def summarize(metrics):
    return {
        'pose_mAP50': round(float(metrics.pose.map50), 4),
        'pose_mAP50_95': round(float(metrics.pose.map), 4),
        'pose_precision': round(float(metrics.pose.mp), 4),
        'pose_recall': round(float(metrics.pose.mr), 4),
        'box_mAP50': round(float(metrics.box.map50), 4),
        'box_mAP50_95': round(float(metrics.box.map), 4),
    }

baseline = summarize(baseline_metrics)
print(json.dumps(baseline, indent=2))
# Out:
# /Users/huynh/projects/deepleaning/k64/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n-pose.pt to 'yolo26n-pose.pt': 100% ━━━━━━━━━━━━ 7.5MB 10.7MB/s 0.7s.7s<0.0s9s.9s
# Ultralytics 8.4.153 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1 Pro)
# YOLO26n-pose summary (fused): 129 layers, 2,926,494 parameters, 0 gradients, 7.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2198.2±1456.3 MB/s, size: 80.3 KB)
# val: Scanning /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/labels/test... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 396.9it/s 0.0s
# val: New cache created: /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/labels/test.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.4it/s 0.7s
#                    all         10         13      0.995      0.923      0.979      0.812      0.973      0.846      0.845      0.685
# Speed: 1.6ms preprocess, 63.0ms inference, 0.0ms loss, 1.1ms postprocess per image
# {
#   "pose_mAP50": 0.845,
#   "pose_mAP50_95": 0.6853,
#   "pose_precision": 0.9734,
#   "pose_recall": 0.8462,
#   "box_mAP50": 0.9785,
#   "box_mAP50_95": 0.8119
# }

# %% [markdown]
# ## 3. Fine-tune trên nhãn của bạn
#
# `fliplr=0.5` là augmentation lật ảnh ngang. Ultralytics đọc `flip_idx` trong `data.yaml`
# để đổi tên khớp trái/phải cho ảnh lật. Đây chính là slide 15: nếu nhãn của bạn đảo trái/phải,
# model được dạy cái sai đó **hai lần** - một lần ở ảnh gốc, một lần ở ảnh lật.
#
# Muốn thấy tận mắt: chạy lại cell này với `fliplr=0.0` và so `pose_mAP50-95`.

# %%
model = YOLO(MODEL_NAME)
train_result = model.train(
    data=str(DATA_YAML),
    epochs=80,
    imgsz=640,
    batch=8,
    device=DEVICE,
    workers=2,
    project=str(RUNS),
    name='pose_finetune',
    exist_ok=True,
    seed=20260915,
    fliplr=0.5,
    plots=True,
    patience=30,
)
BEST = Path(model.trainer.best)
print('checkpoint tốt nhất:', BEST)
# Out:
# Ultralytics 8.4.153 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1 Pro)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/data_colab.yaml, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=80, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n-pose.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=pose_finetune, nbs=64, nms=None, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=20260915, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=pose, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   1416840  ultralytics.nn.modules.head.Pose26           [1, [17, 3], 1, True, [64, 128, 256]]
# YOLO26n-pose summary: 363 layers, 3,679,464 parameters, 3,679,464 gradients, 10.4 GFLOPs
#
# Transferred 879/879 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2265.5±1232.9 MB/s, size: 83.8 KB)
# train: Scanning /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/labels/train... 20 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 20/20 2.1Kit/s 0.0s
# train: New cache created: /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/labels/train.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2965.8±1054.3 MB/s, size: 75.8 KB)
# val: Scanning /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/labels/test.cache... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 6.0Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 126 weight(decay=0.0), 186 weight(decay=0.0005), 186 bias(decay=0.0)
# Plotting labels to /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune/labels.jpg...
# Using 20 train, 10 val images for fraction=1.0 at imgsz=640
# Using 0 dataloader workers
# Logging results to /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        1/80         0G      2.448      2.509     0.2868      1.114    0.04225      2.872         10        640: 100% ━━━━━━━━━━━━ 3/3 2.7s/it 8.2s4.1s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.3s/it 1.3s
#                    all         10         13      0.995      0.923      0.982      0.805      0.975      0.846      0.845      0.685
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        2/80         0G      2.151      3.394     0.2359     0.9266    0.03472      4.604         10        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s3.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.988      0.846      0.909      0.419      0.915      0.846      0.813      0.247
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        3/80         0G      1.713      3.806     0.2943     0.9956    0.02406      5.556         16        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.3s3.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.988      0.846      0.909      0.419      0.915      0.846      0.813      0.247
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        4/80         0G      1.984      4.291     0.2832      1.236     0.0255      5.692          9        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s3.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13     0.0403      0.154     0.0195    0.00456      0.182      0.462      0.177     0.0364
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        5/80         0G      2.821      6.032     0.4018      2.248     0.0398      8.522          9        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.3s3.7s0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13     0.0403      0.154     0.0195    0.00456      0.182      0.462      0.177     0.0364
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        6/80         0G      3.091      5.751     0.3771      1.954    0.03958      7.344         10        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s3.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13        0.8      0.154      0.222     0.0758      0.311      0.154      0.179     0.0277
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        7/80         0G      2.627      5.299     0.5491      1.965    0.04368      7.077         10        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s3.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all         10         13        0.8      0.154      0.222     0.0758      0.311      0.154      0.179     0.0277
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        8/80         0G       2.27      5.796     0.4918      2.343    0.02992      7.041         12        640: 100% ━━━━━━━━━━━━ 3/3 2.5s/it 7.6s3.7s8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0s/it 1.0s
#                    all         10         13        0.8      0.154      0.222     0.0758      0.311      0.154      0.179     0.0277
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#        9/80         0G      1.829      5.142     0.4827      2.236     0.0253      7.045         11        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s3.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all         10         13      0.227      0.769      0.304      0.111       0.62      0.154      0.159     0.0419
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       10/80         0G      1.876      5.161     0.5288      1.797    0.03183      7.828          9        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.3s3.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.227      0.769      0.304      0.111       0.62      0.154      0.159     0.0419
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       11/80         0G      1.628      5.661     0.4712        2.2    0.02268      7.492         14        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s3.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.723      0.231      0.412      0.176      0.826      0.154      0.185     0.0491
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       12/80         0G      1.624      4.322     0.3596      2.004    0.02168      5.835         18        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.9s3.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.723      0.231      0.412      0.176      0.826      0.154      0.185     0.0491
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       13/80         0G      1.594      4.649     0.4165      2.069    0.02231      6.547         14        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s3.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.485      0.154      0.252      0.127      0.485      0.154      0.181     0.0795
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       14/80         0G      1.585       4.25     0.4212      1.917    0.02434      6.832          7        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s3.9ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.485      0.154      0.252      0.127      0.485      0.154      0.181     0.0795
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       15/80         0G      1.449      3.918     0.3599      1.814    0.01763      6.314         16        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s3.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.485      0.154      0.252      0.127      0.485      0.154      0.181     0.0795
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       16/80         0G      1.721      4.328     0.3211      1.778    0.02142      5.816         12        640: 100% ━━━━━━━━━━━━ 3/3 2.4s/it 7.2s3.8s2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.193      0.231      0.213     0.0958      0.292      0.154      0.163     0.0489
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       17/80         0G      1.609      3.935     0.3342       1.79    0.01854      6.271         10        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.8s3.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.8s
#                    all         10         13      0.193      0.231      0.213     0.0958      0.292      0.154      0.163     0.0489
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       18/80         0G      1.559      3.711     0.3008      1.728    0.01884      5.677         11        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.8s3.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.443      0.308      0.267     0.0653      0.181      0.308       0.17      0.077
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       19/80         0G      1.562      4.512     0.4318      1.875    0.02214      7.306         11        640: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.7s3.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.443      0.308      0.267     0.0653      0.181      0.308       0.17      0.077
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       20/80         0G      1.522      4.623     0.3426      1.505    0.01983      6.302         18        640: 100% ━━━━━━━━━━━━ 3/3 3.1s/it 9.3s4.2s7s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all         10         13      0.493      0.231      0.298     0.0851       0.11      0.462      0.143     0.0659
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       21/80         0G      1.562      3.863     0.3747      1.589     0.0211      6.159         18        640: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.7s3.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.493      0.231      0.298     0.0851       0.11      0.462      0.143     0.0659
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       22/80         0G      1.515      3.863     0.3535      1.435    0.01864      5.506         13        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s3.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all         10         13      0.493      0.231      0.298     0.0851       0.11      0.462      0.143     0.0659
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       23/80         0G      1.493      4.215      0.379      1.522    0.01904      6.295         10        640: 100% ━━━━━━━━━━━━ 3/3 2.2s/it 6.7s3.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.397      0.538      0.468      0.149      0.226      0.308      0.247      0.106
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       24/80         0G      1.459      3.173     0.3564       1.62    0.01993      6.295         10        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 6.9s3.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.0it/s 1.0s
#                    all         10         13      0.397      0.538      0.468      0.149      0.226      0.308      0.247      0.106
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       25/80         0G      1.478      4.007     0.3748      1.545    0.01962      6.167         15        640: 100% ━━━━━━━━━━━━ 3/3 2.3s/it 7.0s3.6ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2it/s 0.9s
#                    all         10         13      0.363      0.538      0.457      0.131      0.441      0.308      0.347      0.116
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       26/80         0G      1.518      3.864     0.2585      1.648    0.02372      6.464          7        640: 100% ━━━━━━━━━━━━ 3/3 2.6s/it 7.7s3.6s4s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.363      0.538      0.457      0.131      0.441      0.308      0.347      0.116
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       27/80         0G      1.615      4.646     0.4388      1.598    0.02303      7.275         11        640: 100% ━━━━━━━━━━━━ 3/3 2.8s/it 8.4s4.7s8s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all         10         13      0.435      0.462      0.535      0.161      0.611      0.364      0.374     0.0881
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       28/80         0G      1.584       3.82     0.2734      1.586    0.02269      6.545          5        640: 100% ━━━━━━━━━━━━ 3/3 2.8s/it 8.5s3.9s6s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.2s/it 1.2s
#                    all         10         13      0.435      0.462      0.535      0.161      0.611      0.364      0.374     0.0881
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       29/80         0G      1.534      3.568     0.3549      1.291    0.02301      5.695          9        640: 100% ━━━━━━━━━━━━ 3/3 2.9s/it 8.6s4.0ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1it/s 0.9s
#                    all         10         13      0.435      0.462      0.535      0.161      0.611      0.364      0.374     0.0881
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       30/80         0G       1.44      3.621     0.3176       1.45    0.02056      5.408         14        640: 100% ━━━━━━━━━━━━ 3/3 2.9s/it 8.6s4.6s5s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all         10         13       0.49      0.615      0.595      0.177      0.732      0.308      0.357      0.111
#
#       Epoch    GPU_mem   box_loss  pose_loss  kobj_loss   cls_loss    l1_loss   rle_loss  Instances       Size
#       31/80         0G       1.52      3.199     0.3373      1.392    0.02159      5.174         14        640: 100% ━━━━━━━━━━━━ 3/3 3.1s/it 9.2s4.6s1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.1s/it 1.1s
#                    all         10         13       0.49      0.615      0.595      0.177      0.732      0.308      0.357      0.111
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 31 epochs completed in 0.075 hours.
# Optimizer stripped from /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune/weights/last.pt, 7.8MB
# Optimizer stripped from /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune/weights/best.pt, 7.8MB
#
# Validating /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune/weights/best.pt...
# Ultralytics 8.4.153 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1 Pro)
# YOLO26n-pose summary (fused): 129 layers, 2,926,494 parameters, 0 gradients, 7.6 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         10         13      0.995      0.923      0.982      0.805      0.975      0.846      0.845      0.685
# Speed: 0.6ms preprocess, 61.7ms inference, 0.0ms loss, 0.5ms postprocess per image
# Results saved to /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune
# checkpoint tốt nhất: /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_finetune/weights/best.pt

# %% [markdown]
# ## 4. Đánh giá trên đúng tập test
#
# `data.yaml` trỏ `val` tới 10 ảnh test đã có nhãn phát sẵn. Không đổi nó sang train.
#
# `pose_mAP` chấm bằng **OKS** - đúng thước đo bạn đã dùng để chấm nhãn của mình ở
# `tools/evaluate_pose_annotations.py`. Cùng một công thức, một bên đo người, một bên đo model.

# %%
best_model = YOLO(str(BEST))
finetuned_metrics = best_model.val(
    data=str(DATA_YAML), split='val', device=DEVICE, plots=True,
    project=str(RUNS), name='pose_eval', exist_ok=True)
finetuned = summarize(finetuned_metrics)

comparison = {'baseline_' + MODEL_NAME.replace('.pt', ''): baseline, 'finetuned': finetuned,
              'delta': {k: round(finetuned[k] - baseline[k], 4) for k in baseline}}
(OUTPUTS / 'eval_model.json').write_text(json.dumps(comparison, ensure_ascii=False, indent=2))

header = f"{'chỉ số':<16}{'gốc':>10}{'sau fine-tune':>16}{'chênh':>10}"
print(header); print('-' * len(header))
for key in baseline:
    print(f'{key:<16}{baseline[key]:>10.4f}{finetuned[key]:>16.4f}{comparison["delta"][key]:>+10.4f}')
print('\nĐã ghi outputs/eval_model.json')
# Out:
# Ultralytics 8.4.153 🚀 Python-3.9.6 torch-2.8.0 CPU (Apple M1 Pro)
# YOLO26n-pose summary (fused): 129 layers, 2,926,494 parameters, 0 gradients, 7.6 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2527.3±1236.8 MB/s, size: 67.7 KB)
# val: Scanning /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/labels/test.cache... 10 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 10/10 3.2Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Pose(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5it/s 0.7s
#                    all         10         13      0.995      0.923      0.982      0.805      0.975      0.846      0.845      0.685
# Speed: 0.9ms preprocess, 63.2ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/pose_eval
# chỉ số                 gốc   sau fine-tune     chênh
# ----------------------------------------------------
# pose_mAP50          0.8450          0.8450   +0.0000
# pose_mAP50_95       0.6853          0.6853   +0.0000
# pose_precision      0.9734          0.9745   +0.0011
# pose_recall         0.8462          0.8462   +0.0000
# box_mAP50           0.9785          0.9819   +0.0034
# box_mAP50_95        0.8119          0.8054   -0.0065
#
# Đã ghi outputs/eval_model.json

# %% [markdown]
# ## 5. Nhìn tận mắt - 10 ảnh test kèm pose model đoán
#
# Con số ở trên không nói cho bạn biết model sai **kiểu gì**. Bốn kiểu sai của slide 43
# (lệch nhẹ / đảo trái/phải / nhầm người / trượt hẳn) áp cho model y như áp cho người.

# %%
import math

import matplotlib.pyplot as plt
from PIL import Image

PRED_DIR = RUNS / 'predictions'
best_model.predict(source=str(TEST_IMAGES), conf=0.25, device=DEVICE, save=True,
                   project=str(PRED_DIR), name='test', exist_ok=True)
predicted = sorted((PRED_DIR / 'test').glob('*.jpg'))

columns = 5
rows = math.ceil(len(predicted) / columns)
figure, axes = plt.subplots(rows, columns, figsize=(4 * columns, 3.2 * rows))
for axis, path in zip(axes.flat, predicted):
    axis.imshow(Image.open(path)); axis.set_title(path.stem, fontsize=9)
for axis in axes.flat:
    axis.axis('off')
plt.tight_layout(); plt.show()
# Out:
# image 1/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_01.jpg: 640x576 1 person, 88.3ms
# image 2/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_02.jpg: 448x640 1 person, 66.2ms
# image 3/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_03.jpg: 448x640 2 persons, 60.9ms
# image 4/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_04.jpg: 480x640 1 person, 61.2ms
# image 5/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_05.jpg: 640x448 1 person, 59.8ms
# image 6/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_06.jpg: 576x640 2 persons, 76.5ms
# image 7/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_07.jpg: 608x640 1 person, 67.1ms
# image 8/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_08.jpg: 352x640 1 person, 42.2ms
# image 9/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_09.jpg: 480x640 2 persons, 55.7ms
# image 10/10 /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/dataset/images/test/test_10.jpg: 512x640 1 person, 59.3ms
# Speed: 1.4ms preprocess, 63.7ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to /Users/huynh/projects/h20k_vinuni/lv2-3/lab4/K4-L2-DAY04-Nguyen-Xuan-Huynh-2A202602206-KeypointPose/outputs/runs/predictions/test

# %% [markdown]
# ## 6. Nhãn của bạn vs model chấm thử, trên chính tập train
#
# Slide 27: model chấm thử **một lần để đối chiếu, không phải đáp án**. Bạn đã tự gán xong
# và đã qua cổng gold rồi, nên bây giờ mới được nhìn.
#
# Chỗ nào model và bạn lệch nhau nhiều: hoặc model sai (ảnh khó), hoặc nhãn của bạn sai
# (và gold đã chỉ ra rồi). Ghi lại 2-3 ca vào báo cáo.

# %%
from poselib import Person, greedy_match, image_size

OUT_OF_FRAME = 0
rows_out = []
for image_path in sorted(TRAIN_IMAGES.glob('*.jpg')):
    width, height = image_size(image_path)
    mine = parse_yolo_pose_file(TRAIN_LABELS / f'{image_path.stem}.txt')
    prediction = best_model.predict(source=str(image_path), conf=0.25, device=DEVICE, verbose=False)[0]
    theirs = []
    for box, keypoints in zip(prediction.boxes.xywhn.tolist(), prediction.keypoints.data.tolist()):
        points = [(x / width, y / height, 2 if score >= 0.5 else 1) if score > 0.05 else (0.0, 0.0, OUT_OF_FRAME)
                  for x, y, score in keypoints]
        theirs.append(Person(tuple(box), points))
    matched, extra, missed = greedy_match(theirs, mine, width, height)
    for _, _, score in matched:
        rows_out.append((image_path.stem, round(score, 3)))
    if extra or missed:
        rows_out.append((image_path.stem + ' (số người lệch)', f'model {len(theirs)} / bạn {len(mine)}'))

print(f"{'ảnh':<28}{'OKS model vs nhãn của bạn':>28}")
for stem, value in sorted(rows_out, key=lambda r: (isinstance(r[1], str), r[1])):
    print(f'{stem:<28}{value:>28}')
print('\nOKS thấp = model và bạn bất đồng. Xem lại ảnh đó bằng tools/visualize_pose.py.')
# Out:
# ảnh                            OKS model vs nhãn của bạn
# train_15                                           0.668
# train_13                                           0.678
# train_14                                           0.713
# train_03                                           0.754
# train_16                                           0.814
# train_06                                            0.82
# train_11                                           0.832
# train_04                                           0.857
# train_12                                           0.858
# train_01                                           0.864
# train_10                                           0.864
# train_16                                           0.869
# train_09                                           0.884
# train_18                                           0.884
# train_01                                           0.895
# train_02                                           0.905
# train_19                                           0.909
# train_04                                           0.922
# train_07                                           0.928
# train_15                                            0.93
# train_20                                           0.932
# train_05                                           0.938
# train_03                                           0.942
# train_13                                           0.945
# train_17                                           0.967
# train_19                                           0.967
# train_14                                           0.968
# train_08                                           0.974
# train_09 (số người lệch)                 model 2 / bạn 1
# train_10 (số người lệch)                 model 2 / bạn 1
# train_12 (số người lệch)                 model 2 / bạn 1
# train_03 (số người lệch)                 model 3 / bạn 2
# train_13 (số người lệch)                 model 3 / bạn 2
#
# OKS thấp = model và bạn bất đồng. Xem lại ảnh đó bằng tools/visualize_pose.py.

# %% [markdown]
# ## Câu hỏi phân tích để nộp
#
# Trả lời trong `reports/REPORT.md`:
#
# 1. `pose_mAP50-95` thay đổi bao nhiêu sau fine-tune? Nếu nó **giảm**, hãy giải thích:
#    20 ảnh của bạn dạy được model điều gì mà COCO chưa dạy, và nó làm hỏng điều gì?
# 2. `box_mAP` và `pose_mAP` chênh nhau bao nhiêu? Model tìm *người* dễ hơn hay tìm *khớp* dễ hơn?
# 3. Ở mục 5, tìm một ảnh model đoán sai. Gọi tên lỗi theo bốn loại của slide 43.
# 4. Ở mục 6, ảnh nào có OKS thấp nhất giữa bạn và model? Ai đúng - và bạn dựa vào đâu để nói vậy?
# 5. Trong `tools/evaluate_pose_annotations.py` bạn đã có OKS nhãn-của-bạn vs gold.
#    Ảnh nào bạn gán tệ nhất *cũng* là ảnh model đoán tệ nhất? Nếu có, điều đó nói gì về ảnh đó?
